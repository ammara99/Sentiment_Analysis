# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from textblob import TextBlob
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
test = "Hello, how are you ? The weather is great, and Python is awesome."

print(sent_tokenize(test))
# Out:
# ['Hello, how are you ?', 'The weather is great, and Python is awesome.']

# %%
test2=" I am a Programmer, i have also skills of Graphics Designing"
print(word_tokenize(test2))
# Out:
# ['I', 'am', 'a', 'Programmer', ',', 'i', 'have', 'also', 'skills', 'of', 'Graphics', 'Designing']

# %%
text = ''' The titular threat of The Blob has always struck me as the ultimate movie
monster: an insatiably hungry, amoeba-like mass able to penetrate
virtually any safeguard, capable of--as a doomed doctor chillingly
describes it--"assimilating flesh on contact.
Snide comparisons to gelatin be damned, it's a concept with the most
devastating of potential consequences, not unlike the grey goo scenario
proposed by technological theorists fearful of
artificial intelligence run rampant
       '''

test2 = TextBlob(text)

for i in test2.sentences:
    print(i.sentiment.polarity)
# Out:
# 0.06000000000000001
# -0.34166666666666673

# %%
text = ''' When you are set to begin with your tasks, deal with the hardest one 
       at first 
       '''

test2 = TextBlob(text)

for i in test2.sentences:
    print(i.sentiment.polarity)
# Out:
# 0.25

# %%
df= pd.read_csv('clean_data.csv')

# %%
df.head()
# Out:
#                                             original  \
# 0  In the following excerpt, originally published...
# 1                                     by Umberto Eco
# 2  In 1953 Ian Fleming published the first novel ...
# 3  To Spillane, Casino Royale owes, beyond doubt,...
# 4  In the second place Bond is obsessed by an ima...
#
#                                             Document
# 0  following excerpt originally published italian...
# 1                                        umberto eco
# 2  1953 ian fleming published first novel 007 ser...
# 3  spillane casino royale owes beyond doubt least...
# 4  second place bond obsessed image japanese expe...

# %%
TextBlob(df["Document"].iloc[0]).sentiment
# Out:
# Sentiment(polarity=0.215, subjectivity=0.32)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidfconverter = TfidfVectorizer(max_features=1500, min_df=5, max_df=0.7,ngram_range=(1,3) ,stop_words=stopwords.words('english'))
X = tfidfconverter.fit_transform(df["Document"]).toarray()

# %%
tfidfconverter.get_feature_names()
# Out:
# C:\Users\Ammara\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['007',
#  'absolutely',
#  'act',
#  'action',
#  'almost',
#  'already',
#  'also',
#  'always',
#  'ambiguous',
#  'among',
#  'anglo',
#  'anglo saxon',
#  'another',
#  'appearance',
#  'appears',
#  'author',
#  'beginning',
#  'big',
#  'black',
#  'blofeld',
#  'blood',
#  'body',
#  'bond',
#  'book',
#  'call',
#  'case',
#  'casino',
#  'casino royale',
#  'century',
#  'certain',
#  'chance',
#  'character',
#  'characteristic',
#  'chiffre',
#  'choice',
#  'cold',
#  'communist',
#  'conflict',
#  'could',
#  'country',
#  'couple',
#  'course',
#  'cruel',
#  'de',
#  'death',
#  'describe',
#  'description',
#  'detail',
#  'diamond',
#  'different',
#  'doe',
#  'dominated',
#  'dr',
#  'drax',
#  'ear',
#  'either',
#  'element',
#  'elementary',
#  'end',
#  'enemy',
#  'english',
#  'erotic',
#  'escape',
#  'even',
#  'every',
#  'evil',
#  'example',
#  'except',
#  'excess',
#  'eye',
#  'eyelash',
#  'face',
#  'fact',
#  'figure',
#  'final',
#  'first',
#  'five',
#  'fleming',
#  'following',
#  'forever',
#  'form',
#  'four',
#  'free',
#  'free world',
#  'function',
#  'game',
#  'general',
#  'german',
#  'girl',
#  'give',
#  'gold',
#  'goldfinger',
#  'good',
#  'grant',
#  'great',
#  'gun',
#  'ha',
#  'hair',
#  'hand',
#  'head',
#  'help',
#  'honeychile',
#  'hugo',
#  'hugo drax',
#  'human',
#  'idea',
#  'image',
#  'information',
#  'invention',
#  'james',
#  'james bond',
#  'kind',
#  'klebb',
#  'know',
#  'large',
#  'last',
#  'le',
#  'le chiffre',
#  'least',
#  'let',
#  'level',
#  'life',
#  'light',
#  'like',
#  'literary',
#  'literature',
#  'live',
#  'live twice',
#  'lobe',
#  'long',
#  'look',
#  'love',
#  'luxury',
#  'machine',
#  'made',
#  'majesty',
#  'majesty secret',
#  'majesty secret service',
#  'make',
#  'man',
#  'manner',
#  'may',
#  'mean',
#  'method',
#  'might',
#  'model',
#  'moment',
#  'money',
#  'montage',
#  'moonraker',
#  'moral',
#  'mouth',
#  'move',
#  'mr',
#  'mr big',
#  'much',
#  'must',
#  'narrative',
#  'nature',
#  'nose',
#  'novel',
#  'novel fleming',
#  'often',
#  'one',
#  'opposition',
#  'order',
#  'origin',
#  'page',
#  'pair',
#  'part',
#  'perhaps',
#  'phrase',
#  'physical',
#  'place',
#  'plan',
#  'planning',
#  'play',
#  'pleasure',
#  'plot',
#  'point',
#  'posse',
#  'possible',
#  'power',
#  'psychological',
#  'quality',
#  'rather',
#  'reader',
#  'reading',
#  'really',
#  'recall',
#  'red',
#  'red grant',
#  'relationship',
#  'represent',
#  'represents',
#  'rosa',
#  'rosa klebb',
#  'round',
#  'royale',
#  'rule',
#  'russia',
#  'saxon',
#  'say',
#  'scheme',
#  'second',
#  'secret',
#  'secret service',
#  'see',
#  'seem',
#  'seemed',
#  'seen',
#  'sense',
#  'series',
#  'service',
#  'set',
#  'sexually',
#  'short',
#  'show',
#  'situation',
#  'skin',
#  'small',
#  'smile',
#  'solitaire',
#  'sometimes',
#  'soviet',
#  'spillane',
#  'story',
#  'structure',
#  'success',
#  'take',
#  'tale',
#  'technique',
#  'term',
#  'thing',
#  'though',
#  'three',
#  'thunderball',
#  'thus',
#  'tiffany',
#  'time',
#  'torture',
#  'towards',
#  'train',
#  'twice',
#  'two',
#  'typical',
#  'union',
#  'universal',
#  'upon',
#  'variation',
#  'various',
#  'vicarious',
#  'villain',
#  'wa',
#  'well',
#  'white',
#  'whole',
#  'wicked',
#  'wide',
#  'without',
#  'woman',
#  'word',
#  'work',
#  'world',
#  'would',
#  'yet']

# %%
len(tfidfconverter.get_feature_names())
# Out:
# 266

# %%
df['Document'][:]
# Out:
# 0      following excerpt originally published italian...
# 1                                            umberto eco
# 2      1953 ian fleming published first novel 007 ser...
# 3      spillane casino royale owes beyond doubt least...
# 4      second place bond obsessed image japanese expe...
#                              ...
# 119    hand woman fleming cannot accept decadent arch...
# 120    however concerned psychological interpretation...
# 121    message doe really end except concrete local r...
# 122    source eco umberto narrative structure fleming...
# 123             twentieth century literary criticism 193
# Name: Document, Length: 124, dtype: object

# %%
fdist = FreqDist()

# %%
for x in str(df['Document'][:]).split():
    fdist[x]+=1
    
len(fdist)
# Out:
# 72

# %%
fdist.most_common(50)
# Out:
# [('published', 2),
#  ('umberto', 2),
#  ('eco', 2),
#  ('fleming', 2),
#  ('0', 1),
#  ('following', 1),
#  ('excerpt', 1),
#  ('originally', 1),
#  ('italian...', 1),
#  ('1', 1),
#  ('2', 1),
#  ('1953', 1),
#  ('ian', 1),
#  ('first', 1),
#  ('novel', 1),
#  ('007', 1),
#  ('ser...', 1),
#  ('3', 1),
#  ('spillane', 1),
#  ('casino', 1),
#  ('royale', 1),
#  ('owes', 1),
#  ('beyond', 1),
#  ('doubt', 1),
#  ('least...', 1),
#  ('4', 1),
#  ('second', 1),
#  ('place', 1),
#  ('bond', 1),
#  ('obsessed', 1),
#  ('image', 1),
#  ('japanese', 1),
#  ('expe...', 1),
#  ('...', 1),
#  ('119', 1),
#  ('hand', 1),
#  ('woman', 1),
#  ('cannot', 1),
#  ('accept', 1),
#  ('decadent', 1),
#  ('arch...', 1),
#  ('120', 1),
#  ('however', 1),
#  ('concerned', 1),
#  ('psychological', 1),
#  ('interpretation...', 1),
#  ('121', 1),
#  ('message', 1),
#  ('doe', 1),
#  ('really', 1)]

# %%
ser= pd.Series(tfidfconverter.get_feature_names())
ser.count()
# Out:
# 266

# %%
df['polarity']= df["Document"].apply(lambda x : TextBlob(x).sentiment[0])
df['Subjectivity']= df["Document"].apply(lambda x : TextBlob(x).sentiment[1])

# %%
df.head()
# Out:
#                                             original  \
# 0  In the following excerpt, originally published...
# 1                                     by Umberto Eco
# 2  In 1953 Ian Fleming published the first novel ...
# 3  To Spillane, Casino Royale owes, beyond doubt,...
# 4  In the second place Bond is obsessed by an ima...
#
#                                             Document  polarity  Subjectivity
# 0  following excerpt originally published italian...  0.215000      0.320000
# 1                                        umberto eco  0.000000      0.000000
# 2  1953 ian fleming published first novel 007 ser... -0.103704      0.483333
# 3  spillane casino royale owes beyond doubt least...  0.101852      0.455556
# 4  second place bond obsessed image japanese expe... -0.040132      0.318933

# %%
df['Lenght']= df["Document"].apply(lambda x: len(x.split()))

# %%
df.head()
# Out:
#                                             original  \
# 0  In the following excerpt, originally published...
# 1                                     by Umberto Eco
# 2  In 1953 Ian Fleming published the first novel ...
# 3  To Spillane, Casino Royale owes, beyond doubt,...
# 4  In the second place Bond is obsessed by an ima...
#
#                                             Document  polarity  Subjectivity  \
# 0  following excerpt originally published italian...  0.215000      0.320000
# 1                                        umberto eco  0.000000      0.000000
# 2  1953 ian fleming published first novel 007 ser... -0.103704      0.483333
# 3  spillane casino royale owes beyond doubt least...  0.101852      0.455556
# 4  second place bond obsessed image japanese expe... -0.040132      0.318933
#
#    Lenght
# 0      23
# 1       2
# 2      30
# 3      51
# 4      99

# %%
x=len(df)
neg=[]
pos=[]
neu=[]
comp=[]
for i in range(0,x):
    def sa(i):
        score = SentimentIntensityAnalyzer().polarity_scores(i)
        v1 = score['neg']
        positive = score['pos']
        neutral = score['neu']
        compound = score['comp']
        neg.append(v1)
        pos.append(positive)
        neu.append(neutral)
        comp.append(compound)
        
    sa(df["Document"][i])

# %%
df["Negative Sentiment"]=neg
df["Positive Sentiment"]=pos
df["Neutral Sentiment"]=neu
df["Compound Sentiment"]=comp

# %%
df.head(25)
# Out:
#                                              original  \
# 0   In the following excerpt, originally published...
# 1                                      by Umberto Eco
# 2   In 1953 Ian Fleming published the first novel ...
# 3   To Spillane, Casino Royale owes, beyond doubt,...
# 4   In the second place Bond is obsessed by an ima...
# 5   After having helped to dispose of two Bulgaria...
# 6   With this lapidary phrase Fleming defines the ...
# 7   From the psychological point of view a convers...
# 8   In Casino Royale there are already all the ele...
# 9   The juxtaposition of the characters and of val...
# 10          Play situations and the plot as a “game”.
# 11                              A Manichean ideology.
# 12                               Literary techniques.
# 13                             Literature as montage.
# 14  Our enquiry covers the range of the following ...
# 15  Casino Royale, 1953\nLive and Let Die, 1954\nM...
# 16  We shall refer also to the stories in For Your...
# 17  1. The Juxtaposition of the Characters and of ...
# 18  The novels of Fleming seem to be built on a se...
# 19  (a) Bond—M\n(b) Bond—Villain\n(c) Villain—Woma...
# 20  These pairs do not represent “vague” elements ...
# 21  In Bond-M there is a dominated-dominant relati...
# 22  The Bond-M relationship indubitably presuppose...
# 23  Started by M on the road of Duty (at all costs...
# 24  In Diamonds are Forever the villain appears in...
#
#                                              Document  polarity  Subjectivity  \
# 0   following excerpt originally published italian...  0.215000      0.320000
# 1                                         umberto eco  0.000000      0.000000
# 2   1953 ian fleming published first novel 007 ser... -0.103704      0.483333
# 3   spillane casino royale owes beyond doubt least...  0.101852      0.455556
# 4   second place bond obsessed image japanese expe... -0.040132      0.318933
# 5   helped dispose two bulgarian tried get rid suf...  0.007692      0.461538
# 6   lapidary phrase fleming defines character jame... -0.005000      0.433333
# 7   psychological point view conversion ha taken p...  0.029663      0.353968
# 8   casino royale already element building machine...  0.210714      0.304592
# 9                       juxtaposition character value  0.000000      0.000000
# 10                           play situation plot game -0.400000      0.400000
# 11                                 manichean ideology  0.000000      0.000000
# 12                                 literary technique  0.100000      0.100000
# 13                                 literature montage  0.000000      0.000000
# 14  enquiry cover range following novel listed ord...  0.000000      0.300000
# 15  casino royale 1953 live let die 1954 moonraker...  0.093182      0.575000
# 16  shall refer also story eye 1960 man golden gun...  0.500000      0.650000
# 17                    1 juxtaposition character value  0.000000      0.000000
# 18  novel fleming seem built series opposition all... -0.020238      0.233532
# 19  bond b bond villain villain woman woman bond f...  0.650000      0.787500
# 20  pair represent vague element simple one immedi... -0.125000      0.464286
# 21  bond dominated dominant relationship character...  0.173661      0.449405
# 22  bond relationship indubitably presupposes affe...  0.091667      0.566667
# 23  started road duty cost bond enters conflict vi... -0.022058      0.390167
# 24  diamond forever villain appears three differen... -0.064312      0.344203
#
#     Lenght  Negative Sentiment  Positive Sentiment  Neutral Sentiment  \
# 0       23               0.000               0.222              0.778
# 1        2               0.000               0.000              1.000
# 2       30               0.237               0.131              0.631
# 3       51               0.311               0.335              0.354
# 4       99               0.246               0.107              0.648
# 5      151               0.273               0.232              0.495
# 6      101               0.178               0.249              0.573
# 7       53               0.000               0.096              0.904
# 8       74               0.022               0.247              0.731
# 9        3               0.000               0.545              0.455
# 10       4               0.000               0.444              0.556
# 11       2               0.000               0.000              1.000
# 12       2               0.000               0.000              1.000
# 13       2               0.000               0.000              1.000
# 14      15               0.000               0.141              0.859
# 15      28               0.110               0.186              0.704
# 16      20               0.099               0.160              0.741
# 17       4               0.000               0.545              0.455
# 18      42               0.083               0.247              0.671
# 19      33               0.273               0.390              0.337
# 20      22               0.062               0.000              0.938
# 21     183               0.072               0.174              0.754
# 22      43               0.196               0.182              0.623
# 23     169               0.160               0.107              0.733
# 24     108               0.119               0.046              0.835
#
#     Compound Sentiment
# 0               0.7184
# 1               0.0000
# 2              -0.6369
# 3               0.0772
# 4              -0.9485
# 5              -0.8841
# 6               0.6959
# 7               0.6590
# 8               0.9654
# 9               0.3400
# 10              0.3400
# 11              0.0000
# 12              0.0000
# 13              0.0000
# 14              0.3182
# 15              0.4019
# 16              0.3612
# 17              0.3400
# 18              0.7430
# 19              0.7845
# 20             -0.1027
# 21              0.9565
# 22              0.0516
# 23             -0.9313
# 24             -0.8304

# %%
df.loc[df['polarity'] >= 0.001, 'Sentiment p/n'] = 1

df.loc[df['polarity'] <= -0.001, 'Sentiment p/n'] = -1

df.loc[df['polarity'] == 0.0, 'Sentiment p/n'] = 0

df['Sentiment p/n']
# Out:
# 0      1.0
# 1      0.0
# 2     -1.0
# 3      1.0
# 4     -1.0
#       ...
# 119    1.0
# 120    1.0
# 121    1.0
# 122    0.0
# 123    1.0
# Name: Sentiment p/n, Length: 124, dtype: float64

# %%
df
# Out:
#                                               original  \
# 0    In the following excerpt, originally published...
# 1                                       by Umberto Eco
# 2    In 1953 Ian Fleming published the first novel ...
# 3    To Spillane, Casino Royale owes, beyond doubt,...
# 4    In the second place Bond is obsessed by an ima...
# ..                                                 ...
# 119  On the other hand, for woman Fleming cannot ac...
# 120  However, we are not here concerned with a psyc...
# 121  And, again, a message does not really end exce...
# 122  SOURCE: Eco, Umberto. “The Narrative Structure...
# 123       Twentieth-Century literary criticism, n. 193
#
#                                               Document  polarity  \
# 0    following excerpt originally published italian...  0.215000
# 1                                          umberto eco  0.000000
# 2    1953 ian fleming published first novel 007 ser... -0.103704
# 3    spillane casino royale owes beyond doubt least...  0.101852
# 4    second place bond obsessed image japanese expe... -0.040132
# ..                                                 ...       ...
# 119  hand woman fleming cannot accept decadent arch...  0.006250
# 120  however concerned psychological interpretation...  0.187010
# 121  message doe really end except concrete local r...  0.087500
# 122  source eco umberto narrative structure fleming...  0.000000
# 123           twentieth century literary criticism 193  0.100000
#
#      Subjectivity  Lenght  Negative Sentiment  Positive Sentiment  \
# 0        0.320000      23               0.000               0.222
# 1        0.000000       2               0.000               0.000
# 2        0.483333      30               0.237               0.131
# 3        0.455556      51               0.311               0.335
# 4        0.318933      99               0.246               0.107
# ..            ...     ...                 ...                 ...
# 119      0.400000      20               0.176               0.196
# 120      0.593382      82               0.117               0.255
# 121      0.141667      24               0.091               0.000
# 122      0.000000      22               0.000               0.000
# 123      0.100000       5               0.420               0.000
#
#      Neutral Sentiment  Compound Sentiment  Sentiment p/n
# 0                0.778              0.7184            1.0
# 1                1.000              0.0000            0.0
# 2                0.631             -0.6369           -1.0
# 3                0.354              0.0772            1.0
# 4                0.648             -0.9485           -1.0
# ..                 ...                 ...            ...
# 119              0.628              0.1321            1.0
# 120              0.628              0.9289            1.0
# 121              0.909             -0.3182            1.0
# 122              1.000              0.0000            0.0
# 123              0.580             -0.4404            1.0
#
# [124 rows x 10 columns]

# %%
df.to_csv('sentiment_feature_extraction.csv', index=False)

# %%
pd.read_csv('sentiment_feature_extraction.csv')
# Out:
#                                               original  \
# 0    In the following excerpt, originally published...
# 1                                       by Umberto Eco
# 2    In 1953 Ian Fleming published the first novel ...
# 3    To Spillane, Casino Royale owes, beyond doubt,...
# 4    In the second place Bond is obsessed by an ima...
# ..                                                 ...
# 119  On the other hand, for woman Fleming cannot ac...
# 120  However, we are not here concerned with a psyc...
# 121  And, again, a message does not really end exce...
# 122  SOURCE: Eco, Umberto. “The Narrative Structure...
# 123       Twentieth-Century literary criticism, n. 193
#
#                                               Document  polarity  \
# 0    following excerpt originally published italian...  0.215000
# 1                                          umberto eco  0.000000
# 2    1953 ian fleming published first novel 007 ser... -0.103704
# 3    spillane casino royale owes beyond doubt least...  0.101852
# 4    second place bond obsessed image japanese expe... -0.040132
# ..                                                 ...       ...
# 119  hand woman fleming cannot accept decadent arch...  0.006250
# 120  however concerned psychological interpretation...  0.187010
# 121  message doe really end except concrete local r...  0.087500
# 122  source eco umberto narrative structure fleming...  0.000000
# 123           twentieth century literary criticism 193  0.100000
#
#      Subjectivity  Lenght  Negative Sentiment  Positive Sentiment  \
# 0        0.320000      23               0.000               0.222
# 1        0.000000       2               0.000               0.000
# 2        0.483333      30               0.237               0.131
# 3        0.455556      51               0.311               0.335
# 4        0.318933      99               0.246               0.107
# ..            ...     ...                 ...                 ...
# 119      0.400000      20               0.176               0.196
# 120      0.593382      82               0.117               0.255
# 121      0.141667      24               0.091               0.000
# 122      0.000000      22               0.000               0.000
# 123      0.100000       5               0.420               0.000
#
#      Neutral Sentiment  Compound Sentiment  Sentiment p/n
# 0                0.778              0.7184            1.0
# 1                1.000              0.0000            0.0
# 2                0.631             -0.6369           -1.0
# 3                0.354              0.0772            1.0
# 4                0.648             -0.9485           -1.0
# ..                 ...                 ...            ...
# 119              0.628              0.1321            1.0
# 120              0.628              0.9289            1.0
# 121              0.909             -0.3182            1.0
# 122              1.000              0.0000            0.0
# 123              0.580             -0.4404            1.0
#
# [124 rows x 10 columns]
